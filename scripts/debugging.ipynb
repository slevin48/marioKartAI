# %% [markdown]
# ### H5py error

# %%
from train import create_model

model = create_model(keep_prob=1)

# %%
course = 'CM'
weights_file = 'weights/{}.hdf5'.format(course)
model.load_weights(weights_file)

# %%
# solve it
# !pip install h5py==2.10.0 --user

# %% [markdown]
# ### clipboard error
#
# `File "d:/devel/NeuralKart/predict-server.py", line 38,
# in handle`
#
# `File "d:\devel\NeuralKart\env\lib\site-packages\PIL\ImageGrab.py", line 96, in grabclipboard
#     fmt, data = Image.core.grabclipboard_win32()`

# %%
from PIL import Image, ImageGrab

# %%
im = ImageGrab.grabclipboard()

# %%
im
# Out:
# <PIL.BmpImagePlugin.DibImageFile image mode=RGB size=640x480 at 0x25BB4385F08>

# %%
# https://inputs.readthedocs.io/en/latest/user/quickstart.html

from inputs import devices
for device in devices:
    print(device)
# Out:
# Microsoft Keyboard
# Microsoft Mouse
# Microsoft X-Box 360 pad

# %%
import os
# os.chdir('scripts')
from utils import load_sample
# os.chdir('..')

# %%
image_files, joystick_values = load_sample('../samples/2021-10-11-1')

# %%
import os
os.chdir('..')

# %%
import numpy as np
im = np.load("img_prep.npy")
# im = np.load("img_grab.npy")
im.shape
# Out:
# (240, 320, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(im)
